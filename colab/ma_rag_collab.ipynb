# %%
print('helloworld')

# %%
import json

# Open and read JSON file
with open('data.json', 'r', encoding='utf-8') as file:
    data = json.load(r'D:\\RAG_CHAT_BOT_MRAGE\\data\\benchmark.json')

print(data)

# %%
# !nvidia-smi
